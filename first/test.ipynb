# %%
# !pip install google-colab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 1.7 MB/s eta 0:00:001.6 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.5/104.5 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 kB 1.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 5.0 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
# ...

# %%
# Import necessary libraries
import time

# Install google-colab package if not installed
# !pip install google-colab

# Check for the secret module
try:
    from google.colab import secret
except ImportError:
    print("Error: The 'secret' module is not available. Check your google-colab version or refer to Colab documentation.")

# Load API keys from Colab's Secret Manager
try:
    userdata = secret.get_secret("userdata")  # Replace "userdata" with the actual secret name
except Exception as e:
    print(f"Error loading secrets: {e}")
# Out:
# ...
#   Using cached google-colab-1.0.0.tar.gz (72 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
# ...
#   Using cached ipykernel-4.6.1-py3-none-any.whl (104 kB)
# ...
#   Using cached ipython-5.5.0-py3-none-any.whl (758 kB)
# ...
#   Using cached notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
# ...
#   Using cached six-1.12.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached pandas-0.24.2.tar.gz (11.8 MB)
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       /tmp/pip-install-bd0hqrl2/pandas_f196cfe7f3764fc58dee01e50ed7a620/setup.py:12: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#         import pkg_resources
# ...

# %%
import os
import json
import requests
import openai
import time
from google.colab import secret

# Load API keys from Colab's Secret Manager
try:
    userdata = secret.get_secret("userdata")  # Replace "userdata" with the actual secret name
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
    FMP_API_KEY = userdata.get('FMP_API_KEY')
except Exception as e:
    print(f"Error loading secrets: {e}")
    # Handle the error appropriately, such as exiting the script or providing default values.

# Set environment variables
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
os.environ["FMP_API_KEY"] = FMP_API_KEY

# Assuming you're using the openai module for GPT-3
openai.api_key = OPENAI_API_KEY

# Now you can use the OpenAI API and other APIs in your code
# Example usage:
response = openai.Completion.create(
    engine="text-davinci-002",
    prompt="What is the meaning of life?",
    max_tokens=50
)

print(response["choices"][0]["text"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 6
#       4 import openai
#       5 import time
# ----> 6 from google.colab import secret
#       8 # Load API keys from Colab's Secret Manager
#       9 try:
#
# ModuleNotFoundError: No module named 'google.colab'
